# %% [markdown]
# ### COMP 293 Python Project

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
layoff = pd.read_csv("layoffs.csv")
layoff
# Out:
#             company        location        industry  total_laid_off  \
# 0          Just Eat          London            Food          1700.0
# 1           Marvell     SF Bay Area        Hardware           320.0
# 2         Workhuman          Dublin              HR           130.0
# 3        FreshBooks         Toronto         Finance            80.0
# 4              Xing         Hamburg              HR            68.0
# ...             ...             ...             ...             ...
# 2409   HopSkipDrive     Los Angeles  Transportation             8.0
# 2410    Panda Squad     SF Bay Area        Consumer             6.0
# 2411  Tamara Mellon     Los Angeles          Retail            20.0
# 2412       EasyPost  Salt Lake City       Logistics            75.0
# 2413      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off        date     stage         country  funds_raised
# ...

# %%
#a. Brainstorm at least five questions that you could try to answer with your data.
# What the industry distribution within bay area? 
# what's the relationship between industry and precentage of the amount of laid off? 
# During to the pemdemic is there a huge amount of laid off amount rather then other years? 
# Is there any relationship between funds_raised and total_laid_off? 
# Waht the dustribution of industry based all the countries in this database?

# %%
us_layoff = layoff[layoff["location"] == "SF Bay Area" ]
us_layoff
# Out:
#           company     location       industry  total_laid_off  \
# 1         Marvell  SF Bay Area       Hardware           320.0
# 12       Coherent  SF Bay Area  Manufacturing           108.0
# 14    Course Hero  SF Bay Area      Education            42.0
# 17     Freshworks  SF Bay Area        Support             NaN
# 23           Meta  SF Bay Area       Consumer         10000.0
# ...           ...          ...            ...             ...
# 2387   Triplebyte  SF Bay Area     Recruiting            15.0
# 2388  Ladder Life  SF Bay Area        Finance            13.0
# 2389        Cabin  SF Bay Area         Travel             NaN
# 2399       Ejento  SF Bay Area     Recruiting            84.0
# 2410  Panda Squad  SF Bay Area       Consumer             6.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# 1                    0.04  2023-03-21  Post-IPO  United States           NaN
# ...

# %%
sns.displot(data= us_layoff, y= "industry") 
# As u can see in the plot, within bay area,
#Finanace industry has the highest amount within bay area and following one is Healthcare.

# %%
#c. Extra credit for all students:
#d. Check your dataset for columns with outliers that you may want to filter out. Note down
#any columns that you plan on filtering on, and the values that you will filter out.

# %%
sns.pairplot(layoff)

# %%
# The outliner we would like to filter out is fund_raised

# %%
sns.relplot(data = layoff, x= "percentage_laid_off", y= "funds_raised")
# as you can see in the plot, the funds_raised has some of the outliner, So we try to filtering out

# %%
filter_layoff = layoff[layoff["funds_raised"] < 5000]
filter_layoff
# Out:
#             company        location        industry  total_laid_off  \
# 2         Workhuman          Dublin              HR           130.0
# 3        FreshBooks         Toronto         Finance            80.0
# 5            Mr Yum       Melbourne            Food            40.0
# 6         Smallcase       Bengaluru         Finance            15.0
# 7            Laybuy        Auckland         Finance             NaN
# ...             ...             ...             ...             ...
# 2408        Service     Los Angeles          Travel             NaN
# 2409   HopSkipDrive     Los Angeles  Transportation             8.0
# 2410    Panda Squad     SF Bay Area        Consumer             6.0
# 2411  Tamara Mellon     Los Angeles          Retail            20.0
# 2412       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
sns.relplot(data = filter_layoff, x= "percentage_laid_off", y= "funds_raised")
